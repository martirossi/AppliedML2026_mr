# %% [markdown]
# <a href="https://colab.research.google.com/github/martirossi/AppliedML2026_mr/blob/main/initialProject_MR_description.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile Description_MartinaRossi.txt
# Model: LightGBM (classification)
# Features used: 12
# Hyperparameters: learning_rate=0.05, num_leaves=31, max_depth=7
# Notes: Tuned with random search.
#
# Model: MLP (regression)
# Features used: 20
# Hyperparameters: hidden_layers=[64,32], activation='relu'
# Notes: Early stopping applied.
#
# Model: KMeans (clustering)
# Features used: 6
# Hyperparameters: n_clusters=20
# Notes: Standardized features before clustering.
# Out:
# Writing Description_MartinaRossi.txt
